# %%
import pandas as pd

# %%
lh_path = "C:\\Users\\ytsma22c\\Google Drive\\Misc Work\\LOD paper\\ChemLIBS_LOD_calcs_byhand.csv"
lod_hand = pd.read_csv(lh_path)
la_path = "C:\\Users\\ytsma22c\\Google Drive\\Misc Work\\LOD paper\\LOD_calcs.csv"
lod_auto = pd.read_csv(la_path)
th_path = "C:\\Users\\ytsma22c\\Google Drive\\Misc Work\\LOD paper\\ChemLIBS_test_calcs_byhand.csv"
test_hand = pd.read_csv(th_path)
ta_path = "C:\\Users\\ytsma22c\\Google Drive\\Misc Work\\LOD paper\\test_calcs.csv"
test_auto = pd.read_csv(ta_path)

# %%
lod_hand.columns == lod_auto.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
lod = lod_hand.append(lod_auto).reset_index(drop=True)
lod
# Out:
#    element instrument atmosphere num_range         vector  LOB_Braga  \
# 0     SiO2   ChemLIBS       Mars     0-750    9027.525145   4.200157
# 1      MnO   ChemLIBS       Mars     0-750     260.473316   0.121188
# 2     Na2O   ChemLIBS       Mars     0-750     826.045923   0.384327
# 3       Li   ChemLIBS       Mars     0-750    8164.698980   3.798717
# 4       Ni   ChemLIBS       Mars     0-750   15529.825720   7.225425
# ..     ...        ...        ...       ...            ...        ...
# 67      Pb       LANL       Mars  250-1000     932.453539   0.376879
# 68      Rb       LANL       Mars  250-1000    4578.040971   1.850352
# 69    SiO2       LANL       Mars  250-1000    6311.901011   2.551143
# 70      Sr       LANL       Mars  250-1000  155661.441953  62.915204
# 71      Zn       LANL       Mars  250-1000   17189.667340   6.947716
#
#     LOB_metals   LOD_Braga  LOD_metals   LOQ_Braga  LOQ_metals
# 0     1.752289    8.400313    3.504578   25.455495   10.619934
# ...

# %%
test_hand.columns == test_auto.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
test = test_hand.append(test_auto).reset_index(drop=True)
test
# Out:
#     element instrument atmosphere num_range   Avg_Braga  Avg_metals  \
# 0      SiO2   ChemLIBS       Mars     0-750    3.470097   58.550747
# 1       MnO   ChemLIBS       Mars     0-750    4.044496    0.885416
# 2      Na2O   ChemLIBS       Mars     0-750   58.597755    2.940708
# 3        Li   ChemLIBS       Mars     0-750   40.620303   27.831588
# 4        Ni   ChemLIBS       Mars     0-750  124.003487  103.062296
# ..      ...        ...        ...       ...         ...         ...
# 121      Pb       LANL       Mars     0-750   13.435714   13.435714
# 122      Rb       LANL       Mars     0-750  104.880645   84.050000
# 123    SiO2       LANL       Mars     0-750   57.580648   55.236854
# 124      Sr       LANL       Mars     0-750  457.500000  251.715625
# 125      Zn       LANL       Mars     0-750  104.992754  104.407143
#
#      RMSEP_Braga  RMSEP_metals  R2_Braga  R2_metals
# 0       5.420919      5.418319  0.842805   0.844139
# ...

# %% [markdown]
# ## Export
# Replace the existing `LOD_calcs` and `test_calcs` files

# %%
le_path = "C:\\Users\\ytsma22c\\Google Drive\\Misc Work\\LOD paper\\LOD_calcs.csv"
te_path = "C:\\Users\\ytsma22c\\Google Drive\\Misc Work\\LOD paper\\test_calcs.csv"
lod.to_csv(le_path, index=False)
test.to_csv(te_path, index=False)
